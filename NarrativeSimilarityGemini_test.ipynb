# %% [markdown]
# <a href="https://colab.research.google.com/github/DVORA-AZARKOVICH/Narrative-Similarity/blob/main/NarrativeSimilarityGemini_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Narrative Similarity: Gemini Distillation & Embeddings (Test Phase)
# **SemEval-2026 Task 4: Narrative Similarity**
#
# This notebook executes the **Distill-then-Embed** pipeline.
# 1.  **Distill:** Extracts the "Narrative Core" (Theme, Action, Outcomes) using **Gemini 1.5 Flash**.
# 2.  **Embed:** Converts the distilled text into vectors using **Text-Embedding-004**.
# 3.  **Predict:** Computes Cosine Similarity to determine if the Anchor story is closer to Text A or Text B.

# %% [markdown]
# ## 1. Setup Environment
# Installing the Google GenAI SDK, mounting Google Drive, and configuring the API key.

# %%
# !pip install -q -U google-generativeai

import google.genai as genai
import pandas as pd
from tqdm import tqdm
import time
import os
from google.colab import drive

drive.mount('/content/drive')

from google.colab import userdata
try:
    GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
except:
    print("Please set your GOOGLE_API_KEY in the Colab secrets or manually here.")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Load Data
# Reading the dataset from the specified path.

# %%
BASE_PATH = '/content/drive/MyDrive/Narrative Similarity Data/'

SYNTHETIC_FILE = BASE_PATH + 'synthetic_data_for_classification.jsonl'
df_synthetic = pd.read_json(SYNTHETIC_FILE, lines=True)
print("--- Synthetic Data Loaded ---")
print(f"Shape: {df_synthetic.shape}")

DEV_FILE = BASE_PATH + 'SemEval2026-Task_4-dev-v1/dev_track_a.jsonl'
df_dev = pd.read_json(DEV_FILE, lines=True)
print("\n--- Development Data Loaded ---")
print(f"Shape: {df_dev.shape}")

TEST_FILE = BASE_PATH + 'SemEval2026-Task_4-test-v1/test_track_a.jsonl'
df_test = pd.read_json(TEST_FILE, lines=True)
# Out:
# --- Synthetic Data Loaded ---
# Shape: (1900, 5)
#
# --- Development Data Loaded ---
# Shape: (200, 4)

# %%
df_synthetic = df_synthetic.drop(columns=['model_name'])

df_train = df_synthetic.copy()

# %% [markdown]
# ## 3. Narrative Distillation (Gemini 1.5 Flash)
# We define a system prompt that directs the LLM to strip away superficial details (style, names, specific settings) and rewrite the story focusing only on the **abstract theme, course of action, and outcomes**.
#
# This function is then applied to the `anchor`, `text_a`, and `text_b` columns.

# %%
import google.generativeai as genai
from tqdm import tqdm
import pandas as pd

from google.colab import userdata
try:
    if not genai.configure(api_key=GOOGLE_API_KEY):
        pass
except:
    pass

distillation_system_prompt = """
You are an expert annotator tasked with extracting the 'Narrative Core' of a story.

### DEFINITIONS
Extract the core based ONLY on:
1. **Abstract Theme**: The defining constellation of problems and central ideas.
2. **Course of Action**: The sequence of events, actions, conflicts, and turning points.
3. **Outcomes**: The results of the plot (resolution, fates).

### WHAT TO IGNORE
Explicitly REMOVE and IGNORE:
* The concrete setting (e.g., Sci-Fi, Western, dates, locations).
* Names of characters.
* The style of writing.

### OUTPUT INSTRUCTION
Rewrite the story summary to include ONLY the Abstract Theme, Course of Action, and Outcomes. Do not analyze, just describe the narrative core neutrally.
"""

model_distill = genai.GenerativeModel('gemini-1.5-flash',
                                      system_instruction=distillation_system_prompt)

def distill_narrative(text):
    try:
        if not isinstance(text, str): return ""
        response = model_distill.generate_content(text)
        return response.text.strip()
    except Exception as e:
        return text

tqdm.pandas(desc="Distilling Stories")
cols_to_distill = ['anchor_text', 'text_a', 'text_b']

print("Starting distillation...")
for col in cols_to_distill:
    print(f"Distilling column: {col}...")
    try:
        df_test[f'{col}_core'] = df_test[col].progress_apply(distill_narrative)
    except:
        df_test[f'{col}_core'] = df_test[col].apply(distill_narrative)
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# Starting distillation...
# Distilling column: anchor_text...
# Distilling Stories:   0%|          | 0/400 [00:00<?, ?it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1137.11ms
# Distilling Stories:   0%|          | 2/400 [00:01<03:47,  1.75it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.35ms
# Distilling Stories:   1%|          | 4/400 [00:01<02:21,  2.80it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.21ms
# WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 229.07ms
# Distilling Stories:   1%|▏         | 5/400 [00:01<02:03,  3.19it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.72ms
# Distilling Stories:   2%|▏         | 6/400 [00:02<01:56,  3.39it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.14ms
# Distilling Stories:   2%|▏         | 7/400 [00:02<01:47,  3.64it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 279.38ms
# Distilling Stories:   2%|▏         | 8/400 [00:02<01:48,  3.60it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.29ms
# Distilling Stories:   2%|▏         | 9/400 [00:02<01:40,  3.91it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.54ms
# Distilling Stories:   3%|▎         | 11/400 [00:03<01:36,  4.01it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.22ms
# WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278.55ms
# Distilling Stories:   3%|▎         | 12/400 [00:03<01:40,  3.86it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.65ms
# Distilling Stories:   3%|▎         | 13/400 [00:03<01:37,  3.98it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.41ms
# Distilling Stories:   4%|▎         | 14/400 [00:04<01:37,  3.95it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 227.74ms
# Distilling Stories:   4%|▍         | 15/400 [00:04<01:35,  4.05it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.38ms
# Distilling Stories:   4%|▍         | 16/400 [00:04<01:33,  4.12it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.34ms
# Distilling Stories:   4%|▍         | 17/400 [00:04<01:34,  4.05it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.27ms
# Distilling Stories:   4%|▍         | 18/400 [00:05<01:32,  4.12it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 279.04ms
# Distilling Stories:   5%|▍         | 19/400 [00:05<01:37,  3.92it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.16ms
# Distilling Stories:   5%|▌         | 20/400 [00:05<01:31,  4.16it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 530.45ms
# Distilling Stories:   5%|▌         | 21/400 [00:06<02:04,  3.04it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.86ms
# Distilling Stories:   6%|▌         | 22/400 [00:06<01:50,  3.42it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.02ms
# Distilling Stories:   6%|▌         | 23/400 [00:06<01:46,  3.55it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.82ms
# Distilling Stories:   6%|▌         | 24/400 [00:06<01:37,  3.86it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.21ms
# Distilling Stories:   6%|▋         | 25/400 [00:06<01:37,  3.86it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.32ms
# Distilling Stories:   6%|▋         | 26/400 [00:07<01:31,  4.11it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 254.36ms
# Distilling Stories:   7%|▋         | 27/400 [00:07<01:32,  4.03it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.01ms
# Distilling Stories:   7%|▋         | 28/400 [00:07<01:27,  4.24it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278.73ms
# Distilling Stories:   7%|▋         | 29/400 [00:07<01:32,  4.00it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.34ms
# Distilling Stories:   8%|▊         | 30/400 [00:08<01:33,  3.97it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 229.37ms
# Distilling Stories:   8%|▊         | 31/400 [00:08<01:30,  4.06it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.09ms
# Distilling Stories:   8%|▊         | 32/400 [00:08<01:29,  4.13it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.53ms
# Distilling Stories:   8%|▊         | 33/400 [00:08<01:27,  4.18it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.44ms
# Distilling Stories:   8%|▊         | 34/400 [00:09<01:29,  4.08it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.61ms
# Distilling Stories:   9%|▉         | 35/400 [00:09<01:28,  4.14it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.47ms
# Distilling Stories:   9%|▉         | 36/400 [00:09<01:26,  4.19it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.76ms
# Distilling Stories:   9%|▉         | 37/400 [00:09<01:28,  4.09it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.05ms
# Distilling Stories:  10%|▉         | 38/400 [00:10<01:27,  4.15it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.54ms
# Distilling Stories:  10%|▉         | 39/400 [00:10<01:25,  4.20it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.10ms
# Distilling Stories:  10%|█         | 40/400 [00:10<01:25,  4.23it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.67ms
# Distilling Stories:  10%|█         | 41/400 [00:10<01:27,  4.12it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.27ms
# Distilling Stories:  11%|█         | 43/400 [00:11<01:25,  4.17it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.73ms
# WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.35ms
# Distilling Stories:  11%|█         | 44/400 [00:11<01:24,  4.21it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.21ms
# Distilling Stories:  11%|█▏        | 45/400 [00:11<01:23,  4.24it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.34ms
# Distilling Stories:  12%|█▏        | 46/400 [00:12<01:23,  4.26it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.56ms
# Distilling Stories:  12%|█▏        | 47/400 [00:12<01:25,  4.14it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.26ms
# Distilling Stories:  12%|█▏        | 48/400 [00:12<01:21,  4.32it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.58ms
# Distilling Stories:  12%|█▏        | 49/400 [00:12<01:21,  4.31it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.61ms
# Distilling Stories:  12%|█▎        | 50/400 [00:12<01:23,  4.17it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.21ms
# Distilling Stories:  13%|█▎        | 51/400 [00:13<01:22,  4.21it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.31ms
# Distilling Stories:  13%|█▎        | 52/400 [00:13<01:22,  4.24it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 229.36ms
# Distilling Stories:  13%|█▎        | 53/400 [00:13<01:21,  4.25it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.60ms
# Distilling Stories:  14%|█▎        | 54/400 [00:13<01:23,  4.13it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.11ms
# Distilling Stories:  14%|█▍        | 55/400 [00:14<01:19,  4.32it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.43ms
# Distilling Stories:  14%|█▍        | 56/400 [00:14<01:22,  4.18it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.09ms
# Distilling Stories:  14%|█▍        | 57/400 [00:14<01:18,  4.35it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.25ms
# Distilling Stories:  14%|█▍        | 58/400 [00:14<01:18,  4.33it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.71ms
# Distilling Stories:  15%|█▍        | 59/400 [00:15<01:18,  4.32it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.19ms
# Distilling Stories:  15%|█▌        | 60/400 [00:15<01:18,  4.32it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.44ms
# Distilling Stories:  15%|█▌        | 61/400 [00:15<01:18,  4.32it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.41ms
# Distilling Stories:  16%|█▌        | 62/400 [00:15<01:20,  4.18it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.41ms
# Distilling Stories:  16%|█▌        | 63/400 [00:15<01:17,  4.35it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278.59ms
# Distilling Stories:  16%|█▌        | 64/400 [00:16<01:22,  4.07it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.27ms
# Distilling Stories:  16%|█▋        | 65/400 [00:16<01:20,  4.14it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.26ms
# Distilling Stories:  16%|█▋        | 66/400 [00:16<01:22,  4.06it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.65ms
# Distilling Stories:  17%|█▋        | 67/400 [00:17<01:23,  4.00it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.49ms
# Distilling Stories:  17%|█▋        | 68/400 [00:17<01:23,  3.96it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.69ms
# Distilling Stories:  17%|█▋        | 69/400 [00:17<01:21,  4.05it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.81ms
# Distilling Stories:  18%|█▊        | 70/400 [00:17<01:22,  4.00it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.20ms
# Distilling Stories:  18%|█▊        | 71/400 [00:17<01:20,  4.08it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278.99ms
# Distilling Stories:  18%|█▊        | 73/400 [00:18<01:21,  4.02it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.32ms
# WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278
/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 380.72ms
# Distilling Stories:  85%|████████▍ | 339/400 [01:33<00:20,  3.02it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 304.19ms
# Distilling Stories:  85%|████████▌ | 341/400 [01:34<00:21,  2.74it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 455.84ms
# WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 279.81ms
# Distilling Stories:  86%|████████▌ | 342/400 [01:34<00:19,  2.93it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.49ms
# Distilling Stories:  86%|████████▌ | 343/400 [01:34<00:18,  3.17it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 279.09ms
# Distilling Stories:  86%|████████▌ | 344/400 [01:34<00:17,  3.27it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 304.17ms
# Distilling Stories:  86%|████████▋ | 345/400 [01:35<00:16,  3.26it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 254.15ms
# Distilling Stories:  86%|████████▋ | 346/400 [01:35<00:15,  3.42it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 254.18ms
# Distilling Stories:  87%|████████▋ | 347/400 [01:35<00:14,  3.54it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278.88ms
# Distilling Stories:  87%|████████▋ | 348/400 [01:36<00:14,  3.54it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.73ms
# Distilling Stories:  87%|████████▋ | 349/400 [01:36<00:14,  3.64it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.70ms
# Distilling Stories:  88%|████████▊ | 350/400 [01:36<00:13,  3.71it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 304.67ms
# Distilling Stories:  88%|████████▊ | 351/400 [01:36<00:13,  3.55it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 354.55ms
# Distilling Stories:  88%|████████▊ | 352/400 [01:37<00:14,  3.28it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 379.84ms
# Distilling Stories:  88%|████████▊ | 353/400 [01:37<00:15,  3.04it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 329.37ms
# Distilling Stories:  88%|████████▊ | 354/400 [01:37<00:15,  3.03it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.47ms
# Distilling Stories:  89%|████████▉ | 355/400 [01:38<00:13,  3.24it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.13ms
# Distilling Stories:  89%|████████▉ | 356/400 [01:38<00:12,  3.50it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 254.07ms
# Distilling Stories:  89%|████████▉ | 357/400 [01:38<00:11,  3.60it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278.76ms
# Distilling Stories:  90%|████████▉ | 358/400 [01:39<00:11,  3.58it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 379.99ms
# Distilling Stories:  90%|████████▉ | 359/400 [01:39<00:12,  3.21it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 354.84ms
# Distilling Stories:  90%|█████████ | 360/400 [01:39<00:13,  3.07it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 354.94ms
# Distilling Stories:  90%|█████████ | 361/400 [01:40<00:13,  2.98it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278.78ms
# Distilling Stories:  90%|█████████ | 362/400 [01:40<00:12,  3.12it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278.72ms
# Distilling Stories:  91%|█████████ | 363/400 [01:40<00:11,  3.24it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.70ms
# Distilling Stories:  91%|█████████ | 364/400 [01:40<00:10,  3.40it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 279.06ms
# Distilling Stories:  91%|█████████▏| 365/400 [01:41<00:10,  3.44it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.79ms
# Distilling Stories:  92%|█████████▏| 367/400 [01:41<00:09,  3.55it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278.75ms
# WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 279.30ms
# Distilling Stories:  92%|█████████▏| 368/400 [01:42<00:09,  3.54it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.91ms
# Distilling Stories:  92%|█████████▏| 369/400 [01:42<00:08,  3.64it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278.76ms
# Distilling Stories:  92%|█████████▎| 370/400 [01:42<00:08,  3.61it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 253.49ms
# Distilling Stories:  93%|█████████▎| 371/400 [01:42<00:07,  3.68it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 354.85ms
# Distilling Stories:  93%|█████████▎| 372/400 [01:43<00:08,  3.36it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.62ms
# Distilling Stories:  93%|█████████▎| 373/400 [01:43<00:07,  3.59it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 254.64ms
# Distilling Stories:  94%|█████████▎| 374/400 [01:43<00:07,  3.67it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 278.90ms
# Distilling Stories:  94%|█████████▍| 375/400 [01:43<00:06,  3.63it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 279.14ms
# Distilling Stories:  94%|█████████▍| 376/400 [01:44<00:06,  3.60it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 279.13ms
# Distilling Stories:  94%|█████████▍| 377/400 [01:44<00:06,  3.57it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.67ms
# Distilling Stories:  94%|█████████▍| 378/400 [01:44<00:05,  3.76it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 304.36ms
# Distilling Stories:  95%|█████████▍| 379/400 [01:45<00:05,  3.59it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 279.50ms
# Distilling Stories:  95%|█████████▌| 380/400 [01:45<00:05,  3.57it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 279.37ms
# Distilling Stories:  95%|█████████▌| 381/400 [01:45<00:05,  3.56it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 254.29ms
# Distilling Stories:  96%|█████████▌| 382/400 [01:45<00:04,  3.65it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 279.16ms
# Distilling Stories:  96%|█████████▌| 383/400 [01:46<00:04,  3.61it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.17ms
# Distilling Stories:  96%|█████████▌| 384/400 [01:46<00:04,  3.90it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.88ms
# Distilling Stories:  96%|█████████▋| 385/400 [01:46<00:03,  4.13it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.59ms
# Distilling Stories:  96%|█████████▋| 386/400 [01:46<00:03,  4.18it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.38ms
# Distilling Stories:  97%|█████████▋| 387/400 [01:47<00:02,  4.35it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 481.01ms
# Distilling Stories:  97%|█████████▋| 388/400 [01:47<00:03,  3.26it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.56ms
# Distilling Stories:  97%|█████████▋| 389/400 [01:47<00:03,  3.52it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 229.20ms
# Distilling Stories:  98%|█████████▊| 390/400 [01:48<00:02,  3.72it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.74ms
# Distilling Stories:  98%|█████████▊| 391/400 [01:48<00:02,  3.99it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.26ms
# Distilling Stories:  98%|█████████▊| 392/400 [01:48<00:01,  4.21it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.23ms
# Distilling Stories:  98%|█████████▊| 393/400 [01:48<00:01,  4.37it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.01ms
# Distilling Stories:  98%|█████████▊| 394/400 [01:48<00:01,  4.49it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.06ms
# Distilling Stories:  99%|█████████▉| 395/400 [01:49<00:01,  4.58it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 632.59ms
# Distilling Stories:  99%|█████████▉| 396/400 [01:49<00:01,  2.91it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.55ms
# Distilling Stories:  99%|█████████▉| 397/400 [01:49<00:00,  3.22it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 203.55ms
# Distilling Stories: 100%|█████████▉| 398/400 [01:50<00:00,  3.58it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 229.07ms
# Distilling Stories: 100%|█████████▉| 399/400 [01:50<00:00,  3.76it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.28ms
# Distilling Stories: 100%|██████████| 400/400 [01:50<00:00,  3.90it/s]WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 228.72ms
# Distilling Stories: 100%|██████████| 400/400 [01:50<00:00,  3.61it/s]

# %% [markdown]
# ## 4. Embeddings & Similarity Scoring
# We generate vector embeddings for the *distilled* narrative cores using `text-embedding-004`.
# Then, we calculate the **Cosine Similarity** between the Anchor and the two candidates.
#
# * **Logic:** `Predicted_Label = 1` if Similarity(Anchor, A) > Similarity(Anchor, B), else `0`.

# %%
import numpy as np
from numpy.linalg import norm
import google.generativeai as genai
from tqdm import tqdm
import getpass
import pandas as pd

genai.configure(GOOGLE_API_KEY)


EMBEDDING_MODEL = 'models/text-embedding-004'

print(f"\nAttempting to connect to embedding model: {EMBEDDING_MODEL}...")

try:
    test_emb = genai.embed_content(
        model=EMBEDDING_MODEL,
        content="test",
        task_type="semantic_similarity"
    )
    print("✅ SUCCESS! Embedding model found and working.")

except Exception as e:
    print(f"\n❌ Error connecting to {EMBEDDING_MODEL}: {e}")
    print("\n--- Debugging: Available Models for your Key ---")
    try:
        for m in genai.list_models():
            if 'embed' in m.name:
                print(f"- {m.name}")
                if not 'text-embedding-004' in m.name:
                     pass
    except Exception as list_err:
        print(f"Could not list models: {list_err}")

    print("\nIf you see other embedding models above (like 'models/embedding-001'), replace EMBEDDING_MODEL in the code with one of them.")
    raise e


def get_embedding(text):
    if not isinstance(text, str) or not text.strip():
        return np.zeros(768)

    try:
        result = genai.embed_content(
            model=EMBEDDING_MODEL,
            content=text,
            task_type="semantic_similarity"
        )
        return np.array(result['embedding'])
    except Exception as e:
        return np.zeros(768)

def cosine_similarity(vec_a, vec_b):
    if np.all(vec_a == 0) or np.all(vec_b == 0):
        return 0.0
    return np.dot(vec_a, vec_b) / (norm(vec_a) * norm(vec_b))

tqdm.pandas(desc="Embeddings")

print("\n--- Starting Full Embedding Process ---")

cols = ['anchor_text', 'text_a', 'text_b']
suffix = '_core' if 'anchor_text_core' in df_test.columns else ''

print(f"Using columns with suffix: '{suffix}'")

df_test['anchor_emb'] = df_test[f'anchor_text{suffix}'].progress_apply(get_embedding)
df_test['text_a_emb'] = df_test[f'text_a{suffix}'].progress_apply(get_embedding)
df_test['text_b_emb'] = df_test[f'text_b{suffix}'].progress_apply(get_embedding)

print("Calculating Scores...")
df_test['score_a'] = df_test.apply(lambda row: cosine_similarity(row['anchor_emb'], row['text_a_emb']), axis=1)
df_test['score_b'] = df_test.apply(lambda row: cosine_similarity(row['anchor_emb'], row['text_b_emb']), axis=1)

df_test['predicted_label'] = (df_test['score_a'] > df_test['score_b']).astype(bool)

print("\n--- Done! Results Sample ---")
print(df_test[['score_a', 'score_b', 'predicted_label']].head())
# Out:
# Please paste your Google API Key below and press Enter:
# ··········
#
# Attempting to connect to embedding model: models/text-embedding-004...
# ✅ SUCCESS! Embedding model found and working.
#
# --- Starting Full Embedding Process ---
# Using columns with suffix: '_core'
# Embeddings: 100%|██████████| 400/400 [03:02<00:00,  2.20it/s]
# Embeddings: 100%|██████████| 400/400 [02:45<00:00,  2.42it/s]
# Embeddings: 100%|██████████| 400/400 [02:46<00:00,  2.41it/s]
# Calculating Scores...
#
# --- Done! Results Sample ---
#     score_a   score_b  predicted_label
# 0  0.607960  0.661398            False
# 1  0.649949  0.688102            False
# 2  0.567343  0.679646            False
# 3  0.688693  0.620238             True
# 4  0.624853  0.576523             True

# %% [markdown]
# ## 5. Export Results
# Saving the results (including the predictions and embeddings) to a file for backup or submission.

# %%
import zipfile
from google.colab import files

submission_df = df_test[['predicted_label']].copy()

submission_df = submission_df.rename(columns={'predicted_label': 'text_a_is_closer'})

jsonl_filename = 'track_a.jsonl'
submission_df.to_json(jsonl_filename, orient='records', lines=True)
print(f"Saved intermediate JSONL: {jsonl_filename}")

zip_filename = 'submission_zeroshot.zip'
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    zipf.write(jsonl_filename)

print(f"Successfully created: {zip_filename}")

files.download(zip_filename)
# Out:
# Saved intermediate JSONL: track_a.jsonl
# Successfully created: submission_zeroshot.zip
